# %% [markdown]
# <a href="https://colab.research.google.com/github/frostbytewaves-commits/AI-Assistant/blob/main/%D0%9E%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0_%D1%81_%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E_NumPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Работа с рисунками как с массивами точек в формате RGB

# %% [markdown]
# Первым делом вам нужно подключить модуль, который будет отвечать за преобразование файла-рисунка в массив данных в numpy

# %%
x = 100
y = 300
z = x + y
print(z)
# Out:
# 400

# %%
x = int(input())
y = 2 * x
print(y)
# Out:
# 453725378
# 907450756

# %% [markdown]
# ##Модуль PIL

# %%
from PIL import Image
import numpy as np


#скачать данные из файла в массив
img = Image.open("cat.png").convert("RGB")
arr = np.array(img)

#сохранить данные из массива в файл
img = Image.fromarray(arr)
img.save('new.png')

# %%
arr[500][500]
# Out:
# array([97, 24, 41], dtype=uint8)

# %%
arr

# %% [markdown]
# Загрузите файл-изображение в папку в colab.
# 1. Создайте переменную img - которая сохранит содержимое файла
# 2. Сохраните рисунок как массив точкек в формате RGB.
#
# **arr** - массив точек.
#
# Для дальнейшей работы вам нужно копировать исходный массив чтобы не изменять начальный рисунок.
#
# B = A.copy()

# %%
arr2 = arr.copy()
arr3 = np.flip(arr2)
arr3
# Out:
# array([[[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128]],
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128]],
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128]],
#
#        ...,
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128]],
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128]],
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
# ...

# %%
x, y, z = arr3.shape
print(x, y, z)
# Out:
# 922 750 3

# %%
arr3[100:200, :100, :] = [0, 255, 0]
arr3
# Out:
# array([[[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128]],
#
#        [[255,   0,   0],
#         [255,   0,   0],
#         [255,   0,   0],
#         ...,
#         [128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128]],
#
#        ...,
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128]],
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
#         ...,
#         [128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128]],
#
#        [[128, 128, 128],
#         [128, 128, 128],
#         [128, 128, 128],
# ...

# %% [markdown]
# **Полезные методы numpy**

# %%
#Получить размеры ndrray
row, col, d = arr.shape

#Повороты матрицы
B = np.rot90(A)
B = np.flip(A)
B = A.T

#Срезы
B = A[:100, :100]
A[:100, :100] = [:100,:100, [0, 0, 0]]
arr3[:100, :] = [255, 0, 0]

#Методы numpy

bw = np.mean(arr, axis=2).astype(np.uint8) # Считаем среднее по цветам и превращаем обратно в целые числа
bw_rgb = np.stack([bw, bw, bw], axis=2) # Чтобы PIL понял картинку, сделаем из неё обратно 3 одинаковых канала

# %% [markdown]
# #Как с помощью numpy можно изменить рисунок?

# %% [markdown]
# ##Задания

# %% [markdown]
# ### Задание Рамочка
# Сделайте для файла рамку, выбранного цвета из 10 пикселей

# %% [markdown]
# ###Задание Оставь на рисунке только один цвет (R, B или B)

# %% [markdown]
# ### Задание Инвертируйте все цвета на рисунке

# %%
arr5 = 255 - arr
arr5
# Out:
# array([[[127, 127, 127],
#         [127, 127, 127],
#         [127, 127, 127],
#         ...,
#         [127, 127, 127],
#         [127, 127, 127],
#         [127, 127, 127]],
#
#        [[127, 127, 127],
#         [127, 127, 127],
#         [127, 127, 127],
#         ...,
#         [127, 127, 127],
#         [127, 127, 127],
#         [127, 127, 127]],
#
#        [[127, 127, 127],
#         [127, 127, 127],
#         [127, 127, 127],
#         ...,
#         [127, 127, 127],
#         [127, 127, 127],
#         [127, 127, 127]],
#
#        ...,
#
#        [[127, 127, 127],
#         [127, 127, 127],
#         [127, 127, 127],
#         ...,
#         [127, 127, 127],
#         [127, 127, 127],
#         [127, 127, 127]],
#
#        [[127, 127, 127],
#         [127, 127, 127],
#         [127, 127, 127],
#         ...,
#         [127, 127, 127],
#         [127, 127, 127],
#         [127, 127, 127]],
#
#        [[127, 127, 127],
#         [127, 127, 127],
#         [127, 127, 127],
# ...

# %% [markdown]
# ### Задание Создайте ещё одну копию файла с поворотом и сделайте из 2-х файлов один общий

# %% [markdown]
# ###Задание Оттенки серого
# Используйте методы numpy сделайте рисунок в оттенках серого
